# %%
import logging
import importlib
importlib.reload(logging) # see https://stackoverflow.com/a/21475297/1469195
log = logging.getLogger()
log.setLevel('DEBUG')
import sys
logging.basicConfig(format='%(asctime)s %(levelname)s : %(message)s',
                     level=logging.DEBUG, stream=sys.stdout)

import os
os.sys.path.append('/home/schirrmr/braindecode/code/fbcsp/')
os.sys.path.append('/home/schirrmr/braindecode/code/braindecode/')

# %load_ext autoreload
# %autoreload 2
# %cd /home/schirrmr/

import matplotlib
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' 
matplotlib.rcParams['figure.figsize'] = (12.0, 1.0)
matplotlib.rcParams['font.size'] = 7

import logging
log = logging.getLogger()
log.setLevel('DEBUG')
# Out:
# /home/schirrmr

# %%
from braindecode.datasets.bbci import BBCIDataset
set_loader = BBCIDataset('data/BBCI-RGO-Error/MaGlRGO1_1-7.BBCI.mat',
                        load_sensor_names=['C3', 'C4', 'C1', 'C2', 'CPz', 'F3', 'F4', 'Fz'])
cnt = set_loader.load()
cnt = cnt.drop_channels(['STI 014'])

# %%
eog_cnt = BBCIDataset('data/BBCI-RGO-Error/MaGlRGO1_1-7.BBCI.mat',
                        load_sensor_names=['EOG_L', 'EOG_R', 'EOG_U', 'EOG_D',]).load()
eog_cnt = eog_cnt.drop_channels(['STI 014'])
# Out:
# Creating RawArray with float64 data, n_channels=4, n_times=7960276
#     Range : 0 ... 7960275 =      0.000 ...  7960.275 secs
# Ready.
# 2017-09-21 16:05:27,282 WARNING : Same sample has at least two markers.
# 37195: (222 and 17).
# Marker codes will be summed.
# 2017-09-21 16:05:27,283 WARNING : Same sample has at least two markers.
# 59168: (211 and 1).
# Marker codes will be summed.
# 2017-09-21 16:05:27,284 WARNING : Same sample has at least two markers.
# 69681: (111 and 24).
# Marker codes will be summed.
# 2017-09-21 16:05:27,285 WARNING : Same sample has at least two markers.
# 80612: (112 and 33).
# Marker codes will be summed.
# 2017-09-21 16:05:27,286 WARNING : Same sample has at least two markers.
# 93355: (111 and 21).
# Marker codes will be summed.
# 2017-09-21 16:05:27,286 WARNING : Same sample has at least two markers.
# 106201: (222 and 16).
# Marker codes will be summed.
# 2017-09-21 16:05:27,287 WARNING : Same sample has at least two markers.
# 119662: (222 and 20).
# Marker codes will be summed.
# 2017-09-21 16:05:27,288 WARNING : Same sample has at least two markers.
# 132357: (221 and 8).
# Marker codes will be summed.
# 2017-09-21 16:05:27,289 WARNING : Same sample has at least two markers.
# 143870: (211 and 5).
# Marker codes will be summed.
# 2017-09-21 16:05:27,289 WARNING : Same sample has at least two markers.
# 156615: (111 and 25).
# Marker codes will be summed.
# 2017-09-21 16:05:27,290 WARNING : Same sample has at least two markers.
# 168794: (111 and 22).
# Marker codes will be summed.
# 2017-09-21 16:05:27,291 WARNING : Same sample has at least two markers.
# 181456: (112 and 34).
# Marker codes will be summed.
# 2017-09-21 16:05:27,292 WARNING : Same sample has at least two markers.
# 192185: (221 and 10).
# Marker codes will be summed.
# 2017-09-21 16:05:27,292 WARNING : Same sample has at least two markers.
# 204347: (121 and 26).
# Marker codes will be summed.
# 2017-09-21 16:05:27,293 WARNING : Same sample has at least two markers.
# 225991: (222 and 19).
# Marker codes will be summed.
# 2017-09-21 16:05:27,294 WARNING : Same sample has at least two markers.
# 238334: (122 and 38).
# Marker codes will be summed.
# 2017-09-21 16:05:27,295 WARNING : Same sample has at least two markers.
# 249697: (122 and 36).
# Marker codes will be summed.
# 2017-09-21 16:05:27,295 WARNING : Same sample has at least two markers.
# 260926: (122 and 39).
# Marker codes will be summed.
# 2017-09-21 16:05:27,296 WARNING : Same sample has at least two markers.
# 273073: (212 and 13).
# Marker codes will be summed.
# 2017-09-21 16:05:27,297 WARNING : Same sample has at least two markers.
# 285101: (121 and 29).
# Marker codes will be summed.
# 2017-09-21 16:05:27,298 WARNING : Same sample has at least two markers.
# 308108: (122 and 37).
# Marker codes will be summed.
# 2017-09-21 16:05:27,298 WARNING : Same sample has at least two markers.
# 329534: (212 and 14).
# Marker codes will be summed.
# 2017-09-21 16:05:27,299 WARNING : Same sample has at least two markers.
# 340596: (211 and 3).
# Marker codes will be summed.
# 2017-09-21 16:05:27,300 WARNING : Same sample has at least two markers.
# 352075: (111 and 23).
# Marker codes will be summed.
# 2017-09-21 16:05:27,301 WARNING : Same sample has at least two markers.
# 364270: (112 and 32).
# Marker codes will be summed.
# 2017-09-21 16:05:27,301 WARNING : Same sample has at least two markers.
# 376466: (211 and 2).
# Marker codes will be summed.
# 2017-09-21 16:05:27,302 WARNING : Same sample has at least two markers.
# 388811: (212 and 15).
# Marker codes will be summed.
# 2017-09-21 16:05:27,303 WARNING : Same sample has at least two markers.
# 400007: (212 and 12).
# Marker codes will be summed.
# 2017-09-21 16:05:27,304 WARNING : Same sample has at least two markers.
# 411203: (212 and 11).
# Marker codes will be summed.
# 2017-09-21 16:05:27,304 WARNING : Same sample has at least two markers.
# 424748: (221 and 6).
# Marker codes will be summed.
# 2017-09-21 16:05:27,305 WARNING : Same sample has at least two markers.
# 435544: (221 and 9).
# Marker codes will be summed.
# 2017-09-21 16:05:27,306 WARNING : Same sample has at least two markers.
# 457985: (112 and 35).
# Marker codes will be summed.
# 2017-09-21 16:05:27,307 WARNING : Same sample has at least two markers.
# 468981: (221 and 7).
# Marker codes will be summed.
# 2017-09-21 16:05:27,307 WARNING : Same sample has at least two markers.
# 480260: (122 and 40).
# Marker codes will be summed.
# 2017-09-21 16:05:27,308 WARNING : Same sample has at least two markers.
# 492074: (112 and 31).
# Marker codes will be summed.
# 2017-09-21 16:05:27,309 WARNING : Same sample has at least two markers.
# 519176: (222 and 18).
# Marker codes will be summed.
# 2017-09-21 16:05:27,309 WARNING : Same sample has at least two markers.
# 543033: (122 and 38).
# Marker codes will be summed.
# 2017-09-21 16:05:27,310 WARNING : Same sample has at least two markers.
# 554279: (212 and 15).
# Marker codes will be summed.
# 2017-09-21 16:05:27,311 WARNING : Same sample has at least two markers.
# 565625: (222 and 16).
# Marker codes will be summed.
# 2017-09-21 16:05:27,312 WARNING : Same sample has at least two markers.
# 587550: (122 and 37).
# Marker codes will be summed.
# 2017-09-21 16:05:27,312 WARNING : Same sample has at least two markers.
# 598329: (212 and 14).
# Marker codes will be summed.
# 2017-09-21 16:05:27,313 WARNING : Same sample has at least two markers.
# 609092: (211 and 4).
# Marker codes will be summed.
# 2017-09-21 16:05:27,314 WARNING : Same sample has at least two markers.
# 619588: (112 and 31).
# Marker codes will be summed.
# 2017-09-21 16:05:27,315 WARNING : Same sample has at least two markers.
# 630884: (112 and 32).
# Marker codes will be summed.
# 2017-09-21 16:05:27,315 WARNING : Same sample has at least two markers.
# 641763: (111 and 24).
# Marker codes will be summed.
# 2017-09-21 16:05:27,316 WARNING : Same sample has at least two markers.
# 652409: (112 and 34).
# Marker codes will be summed.
# 2017-09-21 16:05:27,317 WARNING : Same sample has at least two markers.
# 662972: (121 and 27).
# Marker codes will be summed.
# 2017-09-21 16:05:27,318 WARNING : Same sample has at least two markers.
# 673668: (221 and 10).
# Marker codes will be summed.
# 2017-09-21 16:05:27,318 WARNING : Same sample has at least two markers.
# 684530: (121 and 28).
# Marker codes will be summed.
# 2017-09-21 16:05:27,319 WARNING : Same sample has at least two markers.
# 694943: (222 and 19).
# Marker codes will be summed.
# 2017-09-21 16:05:27,320 WARNING : Same sample has at least two markers.
# 705639: (211 and 3).
# Marker codes will be summed.
# 2017-09-21 16:05:27,321 WARNING : Same sample has at least two markers.
# 716452: (221 and 6).
# Marker codes will be summed.
# 2017-09-21 16:05:27,321 WARNING : Same sample has at least two markers.
# 728280: (221 and 7).
# Marker codes will be summed.
# 2017-09-21 16:05:27,322 WARNING : Same sample has at least two markers.
# 739093: (122 and 39).
# Marker codes will be summed.
# 2017-09-21 16:05:27,323 WARNING : Same sample has at least two markers.
# 750455: (211 and 1).
# Marker codes will be summed.
# 2017-09-21 16:05:27,324 WARNING : Same sample has at least two markers.
# 762301: (121 and 26).
# Marker codes will be summed.
# 2017-09-21 16:05:27,324 WARNING : Same sample has at least two markers.
# 772964: (212 and 11).
# Marker codes will be summed.
# 2017-09-21 16:05:27,325 WARNING : Same sample has at least two markers.
# 783860: (211 and 2).
# Marker codes will be summed.
# 2017-09-21 16:05:27,326 WARNING : Same sample has at least two markers.
# 794706: (112 and 33).
# Marker codes will be summed.
# 2017-09-21 16:05:27,327 WARNING : Same sample has at least two markers.
# 805501: (122 and 36).
# Marker codes will be summed.
# 2017-09-21 16:05:27,327 WARNING : Same sample has at least two markers.
# 816831: (222 and 17).
# Marker codes will be summed.
# 2017-09-21 16:05:27,328 WARNING : Same sample has at least two markers.
# 827827: (112 and 35).
# Marker codes will be summed.
# 2017-09-21 16:05:27,329 WARNING : Same sample has at least two markers.
# 838689: (212 and 13).
# Marker codes will be summed.
# 2017-09-21 16:05:27,330 WARNING : Same sample has at least two markers.
# 849735: (111 and 25).
# Marker codes will be summed.
# 2017-09-21 16:05:27,330 WARNING : Same sample has at least two markers.
# 861081: (222 and 20).
# Marker codes will be summed.
# 2017-09-21 16:05:27,331 WARNING : Same sample has at least two markers.
# 872576: (111 and 23).
# Marker codes will be summed.
# 2017-09-21 16:05:27,332 WARNING : Same sample has at least two markers.
# 884655: (221 and 9).
# Marker codes will be summed.
# 2017-09-21 16:05:27,333 WARNING : Same sample has at least two markers.
# 895301: (121 and 30).
# Marker codes will be summed.
# 2017-09-21 16:05:27,333 WARNING : Same sample has at least two markers.
# 906180: (211 and 5).
# Marker codes will be summed.
# 2017-09-21 16:05:27,334 WARNING : Same sample has at least two markers.
# 930005: (111 and 21).
# Marker codes will be summed.
# 2017-09-21 16:05:27,335 WARNING : Same sample has at least two markers.
# 940851: (111 and 22).
# Marker codes will be summed.
# 2017-09-21 16:05:27,336 WARNING : Same sample has at least two markers.
# 951413: (221 and 8).
# Marker codes will be summed.
# 2017-09-21 16:05:27,336 WARNING : Same sample has at least two markers.
# 982947: (121 and 27).
# Marker codes will be summed.
# 2017-09-21 16:05:27,337 WARNING : Same sample has at least two markers.
# 994542: (212 and 12).
# Marker codes will be summed.
# 2017-09-21 16:05:27,338 WARNING : Same sample has at least two markers.
# 1005288: (121 and 26).
# Marker codes will be summed.
# 2017-09-21 16:05:27,339 WARNING : Same sample has at least two markers.
# 1016601: (211 and 5).
# Marker codes will be summed.
# 2017-09-21 16:05:27,339 WARNING : Same sample has at least two markers.
# 1027397: (211 and 2).
# Marker codes will be summed.
# 2017-09-21 16:05:27,340 WARNING : Same sample has at least two markers.
# 1038143: (222 and 18).
# Marker codes will be summed.
# 2017-09-21 16:05:27,341 WARNING : Same sample has at least two markers.
# 1049922: (222 and 20).
# Marker codes will be summed.
# 2017-09-21 16:05:27,342 WARNING : Same sample has at least two markers.
# 1061684: (211 and 1).
# Marker codes will be summed.
# 2017-09-21 16:05:27,342 WARNING : Same sample has at least two markers.
# 1072430: (112 and 31).
# Marker codes will be summed.
# 2017-09-21 16:05:27,343 WARNING : Same sample has at least two markers.
# 1083959: (122 and 38).
# Marker codes will be summed.
# 2017-09-21 16:05:27,344 WARNING : Same sample has at least two markers.
# 1095271: (122 and 37).
# Marker codes will be summed.
# 2017-09-21 16:05:27,344 WARNING : Same sample has at least two markers.
# 1106334: (122 and 36).
# Marker codes will be summed.
# 2017-09-21 16:05:27,345 WARNING : Same sample has at least two markers.
# 1117413: (112 and 32).
# Marker codes will be summed.
# 2017-09-21 16:05:27,346 WARNING : Same sample has at least two markers.
# 1128342: (221 and 9).
# Marker codes will be summed.
# 2017-09-21 16:05:27,347 WARNING : Same sample has at least two markers.
# 1139538: (121 and 28).
# Marker codes will be summed.
# 2017-09-21 16:05:27,347 WARNING : Same sample has at least two markers.
# 1150384: (121 and 29).
# Marker codes will be summed.
# 2017-09-21 16:05:27,348 WARNING : Same sample has at least two markers.
# 1162679: (211 and 4).
# Marker codes will be summed.
# 2017-09-21 16:05:27,349 WARNING : Same sample has at least two markers.
# 1173292: (121 and 30).
# Marker codes will be summed.
# 2017-09-21 16:05:27,350 WARNING : Same sample has at least two markers.
# 1183988: (222 and 17).
# Marker codes will be summed.
# 2017-09-21 16:05:27,350 WARNING : Same sample has at least two markers.
# 1196283: (112 and 34).
# Marker codes will be summed.
# 2017-09-21 16:05:27,351 WARNING : Same sample has at least two markers.
# 1207929: (111 and 21).
# Marker codes will be summed.
# 2017-09-21 16:05:27,352 WARNING : Same sample has at least two markers.
# 1220324: (212 and 14).
# Marker codes will be summed.
# 2017-09-21 16:05:27,353 WARNING : Same sample has at least two markers.
# 1233453: (111 and 24).
# Marker codes will be summed.
# 2017-09-21 16:05:27,353 WARNING : Same sample has at least two markers.
# 1244299: (111 and 23).
# Marker codes will be summed.
# 2017-09-21 16:05:27,354 WARNING : Same sample has at least two markers.
# 1255328: (222 and 16).
# Marker codes will be summed.
# 2017-09-21 16:05:27,355 WARNING : Same sample has at least two markers.
# 1266973: (221 and 10).
# Marker codes will be summed.
# 2017-09-21 16:05:27,356 WARNING : Same sample has at least two markers.
# 1277670: (212 and 15).
# Marker codes will be summed.
# 2017-09-21 16:05:27,356 WARNING : Same sample has at least two markers.
# 1299511: (122 and 39).
# Marker codes will be summed.
# 2017-09-21 16:05:27,357 WARNING : Same sample has at least two markers.
# 1310807: (111 and 25).
# Marker codes will be summed.
# 2017-09-21 16:05:27,358 WARNING : Same sample has at least two markers.
# 1321553: (222 and 19).
# Marker codes will be summed.
# 2017-09-21 16:05:27,359 WARNING : Same sample has at least two markers.
# 1332799: (122 and 40).
# Marker codes will be summed.
# 2017-09-21 16:05:27,360 WARNING : Same sample has at least two markers.
# 1344128: (221 and 8).
# Marker codes will be summed.
# 2017-09-21 16:05:27,360 WARNING : Same sample has at least two markers.
# 1354840: (211 and 3).
# Marker codes will be summed.
# 2017-09-21 16:05:27,361 WARNING : Same sample has at least two markers.
# 1365470: (112 and 33).
# Marker codes will be summed.
# 2017-09-21 16:05:27,362 WARNING : Same sample has at least two markers.
# 1376316: (111 and 22).
# Marker codes will be summed.
# 2017-09-21 16:05:27,363 WARNING : Same sample has at least two markers.
# 1386945: (212 and 11).
# Marker codes will be summed.
# 2017-09-21 16:05:27,363 WARNING : Same sample has at least two markers.
# 1398291: (221 and 6).
# Marker codes will be summed.
# 2017-09-21 16:05:27,364 WARNING : Same sample has at least two markers.
# 1409103: (212 and 13).
# Marker codes will be summed.
# 2017-09-21 16:05:27,365 WARNING : Same sample has at least two markers.
# 1584821: (122 and 39).
# Marker codes will be summed.
# 2017-09-21 16:05:27,365 WARNING : Same sample has at least two markers.
# 1595800: (112 and 34).
# Marker codes will be summed.
# 2017-09-21 16:05:27,366 WARNING : Same sample has at least two markers.
# 1606529: (221 and 9).
# Marker codes will be summed.
# 2017-09-21 16:05:27,367 WARNING : Same sample has at least two markers.
# 1617758: (222 and 17).
# Marker codes will be summed.
# 2017-09-21 16:05:27,368 WARNING : Same sample has at least two markers.
# 1628771: (222 and 16).
# Marker codes will be summed.
# 2017-09-21 16:05:27,368 WARNING : Same sample has at least two markers.
# 1640633: (111 and 24).
# Marker codes will be summed.
# 2017-09-21 16:05:27,369 WARNING : Same sample has at least two markers.
# 1651629: (121 and 28).
# Marker codes will be summed.
# 2017-09-21 16:05:27,370 WARNING : Same sample has at least two markers.
# 1662458: (111 and 23).
# Marker codes will be summed.
# 2017-09-21 16:05:27,371 WARNING : Same sample has at least two markers.
# 1673588: (122 and 40).
# Marker codes will be summed.
# 2017-09-21 16:05:27,371 WARNING : Same sample has at least two markers.
# 1686616: (212 and 15).
# Marker codes will be summed.
# 2017-09-21 16:05:27,372 WARNING : Same sample has at least two markers.
# 1709224: (211 and 2).
# Marker codes will be summed.
# 2017-09-21 16:05:27,373 WARNING : Same sample has at least two markers.
# 1719904: (121 and 26).
# Marker codes will be summed.
# 2017-09-21 16:05:27,374 WARNING : Same sample has at least two markers.
# 1730550: (122 and 36).
# Marker codes will be summed.
# 2017-09-21 16:05:27,374 WARNING : Same sample has at least two markers.
# 1753557: (212 and 12).
# Marker codes will be summed.
# 2017-09-21 16:05:27,375 WARNING : Same sample has at least two markers.
# 1764670: (221 and 7).
# Marker codes will be summed.
# 2017-09-21 16:05:27,376 WARNING : Same sample has at least two markers.
# 1798574: (211 and 5).
# Marker codes will be summed.
# 2017-09-21 16:05:27,377 WARNING : Same sample has at least two markers.
# 1809870: (111 and 25).
# Marker codes will be summed.
# 2017-09-21 16:05:27,377 WARNING : Same sample has at least two markers.
# 1822981: (111 and 22).
# Marker codes will be summed.
# 2017-09-21 16:05:27,378 WARNING : Same sample has at least two markers.
# 1836010: (212 and 11).
# Marker codes will be summed.
# 2017-09-21 16:05:27,379 WARNING : Same sample has at least two markers.
# 1847189: (221 and 6).
# Marker codes will be summed.
# 2017-09-21 16:05:27,379 WARNING : Same sample has at least two markers.
# 1858668: (212 and 13).
# Marker codes will be summed.
# 2017-09-21 16:05:27,380 WARNING : Same sample has at least two markers.
# 1870880: (121 and 27).
# Marker codes will be summed.
# 2017-09-21 16:05:27,381 WARNING : Same sample has at least two markers.
# 1883259: (211 and 3).
# Marker codes will be summed.
# 2017-09-21 16:05:27,382 WARNING : Same sample has at least two markers.
# 1895821: (222 and 18).
# Marker codes will be summed.
# 2017-09-21 16:05:27,382 WARNING : Same sample has at least two markers.
# 1906667: (122 and 38).
# Marker codes will be summed.
# 2017-09-21 16:05:27,383 WARNING : Same sample has at least two markers.
# 1917746: (121 and 30).
# Marker codes will be summed.
# 2017-09-21 16:05:27,384 WARNING : Same sample has at least two markers.
# 1930224: (122 and 37).
# Marker codes will be summed.
# 2017-09-21 16:05:27,385 WARNING : Same sample has at least two markers.
# 1941554: (121 and 29).
# Marker codes will be summed.
# 2017-09-21 16:05:27,385 WARNING : Same sample has at least two markers.
# 1952766: (112 and 35).
# Marker codes will be summed.
# 2017-09-21 16:05:27,386 WARNING : Same sample has at least two markers.
# 1977340: (112 and 32).
# Marker codes will be summed.
# 2017-09-21 16:05:27,387 WARNING : Same sample has at least two markers.
# 1988236: (211 and 1).
# Marker codes will be summed.
# 2017-09-21 16:05:27,388 WARNING : Same sample has at least two markers.
# 1998849: (221 and 8).
# Marker codes will be summed.
# 2017-09-21 16:05:27,388 WARNING : Same sample has at least two markers.
# 2009412: (221 and 10).
# Marker codes will be summed.
# 2017-09-21 16:05:27,389 WARNING : Same sample has at least two markers.
# 2253020: (121 and 29).
# Marker codes will be summed.
# 2017-09-21 16:05:27,390 WARNING : Same sample has at least two markers.
# 2264132: (111 and 25).
# Marker codes will be summed.
# 2017-09-21 16:05:27,391 WARNING : Same sample has at least two markers.
# 2276228: (221 and 9).
# Marker codes will be summed.
# 2017-09-21 16:05:27,391 WARNING : Same sample has at least two markers.
# 2286824: (112 and 33).
# Marker codes will be summed.
# 2017-09-21 16:05:27,392 WARNING : Same sample has at least two markers.
# 2298969: (121 and 28).
# Marker codes will be summed.
# 2017-09-21 16:05:27,393 WARNING : Same sample has at least two markers.
# 2310965: (222 and 19).
# Marker codes will be summed.
# 2017-09-21 16:05:27,393 WARNING : Same sample has at least two markers.
# 2322677: (111 and 23).
# Marker codes will be summed.
# 2017-09-21 16:05:27,394 WARNING : Same sample has at least two markers.
# 2334306: (221 and 10).
# Marker codes will be summed.
# 2017-09-21 16:05:27,395 WARNING : Same sample has at least two markers.
# 2347135: (211 and 3).
# Marker codes will be summed.
# 2017-09-21 16:05:27,396 WARNING : Same sample has at least two markers.
# 2358397: (222 and 20).
# Marker codes will be summed.
# 2017-09-21 16:05:27,396 WARNING : Same sample has at least two markers.
# 2381605: (122 and 40).
# Marker codes will be summed.
# 2017-09-21 16:05:27,397 WARNING : Same sample has at least two markers.
# 2394200: (211 and 4).
# Marker codes will be summed.
# 2017-09-21 16:05:27,398 WARNING : Same sample has at least two markers.
# 2405213: (221 and 8).
# Marker codes will be summed.
# 2017-09-21 16:05:27,399 WARNING : Same sample has at least two markers.
# 2416492: (211 and 2).
# Marker codes will be summed.
# 2017-09-21 16:05:27,399 WARNING : Same sample has at least two markers.
# 2429970: (121 and 26).
# Marker codes will be summed.
# 2017-09-21 16:05:27,400 WARNING : Same sample has at least two markers.
# 2441799: (212 and 14).
# Marker codes will be summed.
# 2017-09-21 16:05:27,401 WARNING : Same sample has at least two markers.
# 2452778: (222 and 16).
# Marker codes will be summed.
# 2017-09-21 16:05:27,402 WARNING : Same sample has at least two markers.
# 2465857: (112 and 32).
# Marker codes will be summed.
# 2017-09-21 16:05:27,402 WARNING : Same sample has at least two markers.
# 2477286: (212 and 11).
# Marker codes will be summed.
# 2017-09-21 16:05:27,403 WARNING : Same sample has at least two markers.
# 2490214: (121 and 30).
# Marker codes will be summed.
# 2017-09-21 16:05:27,404 WARNING : Same sample has at least two markers.
# 2502226: (122 and 39).
# Marker codes will be summed.
# 2017-09-21 16:05:27,405 WARNING : Same sample has at least two markers.
# 2514272: (222 and 17).
# Marker codes will be summed.
# 2017-09-21 16:05:27,405 WARNING : Same sample has at least two markers.
# 2528150: (112 and 34).
# Marker codes will be summed.
# 2017-09-21 16:05:27,406 WARNING : Same sample has at least two markers.
# 2539096: (211 and 5).
# Marker codes will be summed.
# 2017-09-21 16:05:27,407 WARNING : Same sample has at least two markers.
# 2551874: (112 and 31).
# Marker codes will be summed.
# 2017-09-21 16:05:27,407 WARNING : Same sample has at least two markers.
# 2563470: (111 and 24).
# Marker codes will be summed.
# 2017-09-21 16:05:27,408 WARNING : Same sample has at least two markers.
# 2575849: (112 and 35).
# Marker codes will be summed.
# 2017-09-21 16:05:27,409 WARNING : Same sample has at least two markers.
# 2587161: (122 and 37).
# Marker codes will be summed.
# 2017-09-21 16:05:27,410 WARNING : Same sample has at least two markers.
# 2612635: (221 and 6).
# Marker codes will be summed.
# 2017-09-21 16:05:27,410 WARNING : Same sample has at least two markers.
# 2624281: (122 and 36).
# Marker codes will be summed.
# 2017-09-21 16:05:27,411 WARNING : Same sample has at least two markers.
# 2636026: (221 and 7).
# Marker codes will be summed.
# 2017-09-21 16:05:27,412 WARNING : Same sample has at least two markers.
# 2649504: (222 and 18).
# Marker codes will be summed.
# 2017-09-21 16:05:27,413 WARNING : Same sample has at least two markers.
# 2663416: (212 and 12).
# Marker codes will be summed.
# 2017-09-21 16:05:27,413 WARNING : Same sample has at least two markers.
# 2674762: (122 and 38).
# Marker codes will be summed.
# 2017-09-21 16:05:27,414 WARNING : Same sample has at least two markers.
# 2686691: (111 and 21).
# Marker codes will be summed.
# 2017-09-21 16:05:27,415 WARNING : Same sample has at least two markers.
# 2698336: (121 and 27).
# Marker codes will be summed.
# 2017-09-21 16:05:27,416 WARNING : Same sample has at least two markers.
# 2710831: (111 and 22).
# Marker codes will be summed.
# 2017-09-21 16:05:27,416 WARNING : Same sample has at least two markers.
# 2721494: (212 and 13).
# Marker codes will be summed.
# 2017-09-21 16:05:27,417 WARNING : Same sample has at least two markers.
# 2831186: (121 and 27).
# Marker codes will be summed.
# 2017-09-21 16:05:27,418 WARNING : Same sample has at least two markers.
# 2842999: (122 and 40).
# Marker codes will be summed.
# 2017-09-21 16:05:27,419 WARNING : Same sample has at least two markers.
# 2854827: (222 and 16).
# Marker codes will be summed.
# 2017-09-21 16:05:27,419 WARNING : Same sample has at least two markers.
# 2865723: (212 and 11).
# Marker codes will be summed.
# 2017-09-21 16:05:27,420 WARNING : Same sample has at least two markers.
# 2877169: (212 and 14).
# Marker codes will be summed.
# 2017-09-21 16:05:27,421 WARNING : Same sample has at least two markers.
# 2901527: (211 and 4).
# Marker codes will be summed.
# 2017-09-21 16:05:27,422 WARNING : Same sample has at least two markers.
# 2912422: (221 and 9).
# Marker codes will be summed.
# 2017-09-21 16:05:27,422 WARNING : Same sample has at least two markers.
# 2924068: (121 and 30).
# Marker codes will be summed.
# 2017-09-21 16:05:27,423 WARNING : Same sample has at least two markers.
# 2936580: (112 and 32).
# Marker codes will be summed.
# 2017-09-21 16:05:27,424 WARNING : Same sample has at least two markers.
# 2947459: (122 and 36).
# Marker codes will be summed.
# 2017-09-21 16:05:27,425 WARNING : Same sample has at least two markers.
# 2959405: (122 and 38).
# Marker codes will be summed.
# 2017-09-21 16:05:27,425 WARNING : Same sample has at least two markers.
# 2970184: (122 and 37).
# Marker codes will be summed.
# 2017-09-21 16:05:27,426 WARNING : Same sample has at least two markers.
# 2980747: (121 and 29).
# Marker codes will be summed.
# 2017-09-21 16:05:27,427 WARNING : Same sample has at least two markers.
# 2992226: (111 and 23).
# Marker codes will be summed.
# 2017-09-21 16:05:27,427 WARNING : Same sample has at least two markers.
# 3004471: (121 and 26).
# Marker codes will be summed.
# 2017-09-21 16:05:27,428 WARNING : Same sample has at least two markers.
# 3014817: (111 and 21).
# Marker codes will be summed.
# 2017-09-21 16:05:27,429 WARNING : Same sample has at least two markers.
# 3026463: (212 and 15).
# Marker codes will be summed.
# 2017-09-21 16:05:27,430 WARNING : Same sample has at least two markers.
# 3037509: (111 and 24).
# Marker codes will be summed.
# 2017-09-21 16:05:27,430 WARNING : Same sample has at least two markers.
# 3049304: (211 and 1).
# Marker codes will be summed.
# 2017-09-21 16:05:27,431 WARNING : Same sample has at least two markers.
# 3061183: (211 and 5).
# Marker codes will be summed.
# 2017-09-21 16:05:27,432 WARNING : Same sample has at least two markers.
# 3073595: (211 and 3).
# Marker codes will be summed.
# 2017-09-21 16:05:27,433 WARNING : Same sample has at least two markers.
# 3086057: (112 and 33).
# Marker codes will be summed.
# 2017-09-21 16:05:27,433 WARNING : Same sample has at least two markers.
# 3098286: (222 and 18).
# Marker codes will be summed.
# 2017-09-21 16:05:27,434 WARNING : Same sample has at least two markers.
# 3109182: (111 and 22).
# Marker codes will be summed.
# 2017-09-21 16:05:27,435 WARNING : Same sample has at least two markers.
# 3120178: (222 and 17).
# Marker codes will be summed.
# 2017-09-21 16:05:27,436 WARNING : Same sample has at least two markers.
# 3131790: (221 and 10).
# Marker codes will be summed.
# 2017-09-21 16:05:27,436 WARNING : Same sample has at least two markers.
# 3144285: (221 and 6).
# Marker codes will be summed.
# 2017-09-21 16:05:27,437 WARNING : Same sample has at least two markers.
# 3155265: (112 and 35).
# Marker codes will be summed.
# 2017-09-21 16:05:27,438 WARNING : Same sample has at least two markers.
# 3166077: (122 and 39).
# Marker codes will be summed.
# 2017-09-21 16:05:27,439 WARNING : Same sample has at least two markers.
# 3177939: (221 and 8).
# Marker codes will be summed.
# 2017-09-21 16:05:27,439 WARNING : Same sample has at least two markers.
# 3188769: (212 and 13).
# Marker codes will be summed.
# 2017-09-21 16:05:27,440 WARNING : Same sample has at least two markers.
# 3199315: (222 and 19).
# Marker codes will be summed.
# 2017-09-21 16:05:27,441 WARNING : Same sample has at least two markers.
# 3212160: (112 and 31).
# Marker codes will be summed.
# 2017-09-21 16:05:27,441 WARNING : Same sample has at least two markers.
# 3223839: (222 and 20).
# Marker codes will be summed.
# 2017-09-21 16:05:27,442 WARNING : Same sample has at least two markers.
# 3236051: (121 and 28).
# Marker codes will be summed.
# 2017-09-21 16:05:27,443 WARNING : Same sample has at least two markers.
# 3249279: (112 and 34).
# Marker codes will be summed.
# 2017-09-21 16:05:27,444 WARNING : Same sample has at least two markers.
# 3260275: (211 and 2).
# Marker codes will be summed.
# 2017-09-21 16:05:27,444 WARNING : Same sample has at least two markers.
# 3272654: (111 and 25).
# Marker codes will be summed.
# 2017-09-21 16:05:27,445 WARNING : Same sample has at least two markers.
# 3283583: (221 and 7).
# Marker codes will be summed.
# 2017-09-21 16:05:27,446 WARNING : Same sample has at least two markers.
# 3335432: (121 and 26).
# Marker codes will be summed.
# 2017-09-21 16:05:27,447 WARNING : Same sample has at least two markers.
# 3346511: (121 and 29).
# Marker codes will be summed.
# 2017-09-21 16:05:27,447 WARNING : Same sample has at least two markers.
# 3357224: (222 and 18).
# Marker codes will be summed.
# 2017-09-21 16:05:27,448 WARNING : Same sample has at least two markers.
# 3368420: (122 and 40).
# Marker codes will be summed.
# 2017-09-21 16:05:27,449 WARNING : Same sample has at least two markers.
# 3390511: (111 and 25).
# Marker codes will be summed.
# 2017-09-21 16:05:27,450 WARNING : Same sample has at least two markers.
# 3401707: (222 and 20).
# Marker codes will be summed.
# 2017-09-21 16:05:27,451 WARNING : Same sample has at least two markers.
# 3414086: (122 and 39).
# Marker codes will be summed.
# 2017-09-21 16:05:27,452 WARNING : Same sample has at least two markers.
# 3426581: (212 and 14).
# Marker codes will be summed.
# 2017-09-21 16:05:27,452 WARNING : Same sample has at least two markers.
# 3437627: (121 and 30).
# Marker codes will be summed.
# 2017-09-21 16:05:27,453 WARNING : Same sample has at least two markers.
# 3448706: (212 and 11).
# Marker codes will be summed.
# 2017-09-21 16:05:27,454 WARNING : Same sample has at least two markers.
# 3459935: (221 and 8).
# Marker codes will be summed.
# 2017-09-21 16:05:27,455 WARNING : Same sample has at least two markers.
# 3471231: (222 and 16).
# Marker codes will be summed.
# 2017-09-21 16:05:27,456 WARNING : Same sample has at least two markers.
# 3482244: (111 and 24).
# Marker codes will be summed.
# 2017-09-21 16:05:27,457 WARNING : Same sample has at least two markers.
# 3492973: (121 and 28).
# Marker codes will be summed.
# 2017-09-21 16:05:27,458 WARNING : Same sample has at least two markers.
# 3503736: (221 and 10).
# Marker codes will be summed.
# 2017-09-21 16:05:27,458 WARNING : Same sample has at least two markers.
# 3515431: (111 and 23).
# Marker codes will be summed.
# 2017-09-21 16:05:27,459 WARNING : Same sample has at least two markers.
# 3527877: (222 and 17).
# Marker codes will be summed.
# 2017-09-21 16:05:27,460 WARNING : Same sample has at least two markers.
# 3538839: (211 and 3).
# Marker codes will be summed.
# 2017-09-21 16:05:27,461 WARNING : Same sample has at least two markers.
# 3550451: (122 and 36).
# Marker codes will be summed.
# 2017-09-21 16:05:27,462 WARNING : Same sample has at least two markers.
# 3563763: (112 and 35).
# Marker codes will be summed.
# 2017-09-21 16:05:27,463 WARNING : Same sample has at least two markers.
# 3574459: (111 and 21).
# Marker codes will be summed.
# 2017-09-21 16:05:27,463 WARNING : Same sample has at least two markers.
# 3586138: (222 and 19).
# Marker codes will be summed.
# 2017-09-21 16:05:27,464 WARNING : Same sample has at least two markers.
# 3596817: (212 and 15).
# Marker codes will be summed.
# 2017-09-21 16:05:27,465 WARNING : Same sample has at least two markers.
# 3608863: (112 and 31).
# Marker codes will be summed.
# 2017-09-21 16:05:27,466 WARNING : Same sample has at least two markers.
# 3620575: (211 and 5).
# Marker codes will be summed.
# 2017-09-21 16:05:27,467 WARNING : Same sample has at least two markers.
# 3633204: (211 and 4).
# Marker codes will be summed.
# 2017-09-21 16:05:27,467 WARNING : Same sample has at least two markers.
# 3644133: (122 and 38).
# Marker codes will be summed.
# 2017-09-21 16:05:27,468 WARNING : Same sample has at least two markers.
# 3655645: (221 and 9).
# Marker codes will be summed.
# 2017-09-21 16:05:27,469 WARNING : Same sample has at least two markers.
# 3668840: (212 and 12).
# Marker codes will be summed.
# 2017-09-21 16:05:27,470 WARNING : Same sample has at least two markers.
# 3679520: (112 and 33).
# Marker codes will be summed.
# 2017-09-21 16:05:27,471 WARNING : Same sample has at least two markers.
# 3703144: (121 and 27).
# Marker codes will be summed.
# 2017-09-21 16:05:27,472 WARNING : Same sample has at least two markers.
# 3714107: (221 and 7).
# Marker codes will be summed.
# 2017-09-21 16:05:27,472 WARNING : Same sample has at least two markers.
# 3725302: (112 and 32).
# Marker codes will be summed.
# 2017-09-21 16:05:27,473 WARNING : Same sample has at least two markers.
# 3736165: (221 and 6).
# Marker codes will be summed.
# 2017-09-21 16:05:27,474 WARNING : Same sample has at least two markers.
# 3749177: (212 and 13).
# Marker codes will be summed.
# 2017-09-21 16:05:27,475 WARNING : Same sample has at least two markers.
# 3759840: (122 and 37).
# Marker codes will be summed.
# 2017-09-21 16:05:27,476 WARNING : Same sample has at least two markers.
# 3773434: (211 and 1).
# Marker codes will be summed.
# 2017-09-21 16:05:27,476 WARNING : Same sample has at least two markers.
# 3787879: (211 and 2).
# Marker codes will be summed.
# 2017-09-21 16:05:27,477 WARNING : Same sample has at least two markers.
# 3864300: (212 and 14).
# Marker codes will be summed.
# 2017-09-21 16:05:27,478 WARNING : Same sample has at least two markers.
# 3875829: (122 and 37).
# Marker codes will be summed.
# 2017-09-21 16:05:27,479 WARNING : Same sample has at least two markers.
# 3887408: (221 and 8).
# Marker codes will be summed.
# 2017-09-21 16:05:27,480 WARNING : Same sample has at least two markers.
# 3898921: (111 and 22).
# Marker codes will be summed.
# 2017-09-21 16:05:27,481 WARNING : Same sample has at least two markers.
# 3910616: (122 and 38).
# Marker codes will be summed.
# 2017-09-21 16:05:27,481 WARNING : Same sample has at least two markers.
# 3923512: (112 and 33).
# Marker codes will be summed.
# 2017-09-21 16:05:27,482 WARNING : Same sample has at least two markers.
# 3936407: (111 and 24).
# Marker codes will be summed.
# 2017-09-21 16:05:27,483 WARNING : Same sample has at least two markers.
# 3946986: (121 and 30).
# Marker codes will be summed.
# 2017-09-21 16:05:27,484 WARNING : Same sample has at least two markers.
# 3958065: (121 and 29).
# Marker codes will be summed.
# 2017-09-21 16:05:27,485 WARNING : Same sample has at least two markers.
# 3971444: (221 and 7).
# Marker codes will be summed.
# 2017-09-21 16:05:27,511 WARNING : Same sample has at least two markers.
# 3983789: (122 and 36).
# Marker codes will be summed.
# 2017-09-21 16:05:27,512 WARNING : Same sample has at least two markers.
# 3996134: (222 and 20).
# Marker codes will be summed.
# 2017-09-21 16:05:27,568 WARNING : Same sample has at least two markers.
# 4007397: (121 and 27).
# Marker codes will be summed.
# 2017-09-21 16:05:27,569 WARNING : Same sample has at least two markers.
# 4019859: (121 and 28).
# Marker codes will be summed.
# 2017-09-21 16:05:27,569 WARNING : Same sample has at least two markers.
# 4044449: (222 and 17).
# Marker codes will be summed.
# 2017-09-21 16:05:27,570 WARNING : Same sample has at least two markers.
# 4067907: (212 and 12).
# Marker codes will be summed.
# 2017-09-21 16:05:27,571 WARNING : Same sample has at least two markers.
# 4078920: (112 and 34).
# Marker codes will be summed.
# 2017-09-21 16:05:27,572 WARNING : Same sample has at least two markers.
# 4091749: (211 and 2).
# Marker codes will be summed.
# 2017-09-21 16:05:27,573 WARNING : Same sample has at least two markers.
# 4104077: (122 and 39).
# Marker codes will be summed.
# 2017-09-21 16:05:27,611 WARNING : Same sample has at least two markers.
# 4115406: (212 and 15).
# Marker codes will be summed.
# 2017-09-21 16:05:27,612 WARNING : Same sample has at least two markers.
# 4126935: (111 and 23).
# Marker codes will be summed.
# 2017-09-21 16:05:27,629 WARNING : Same sample has at least two markers.
# 4139997: (211 and 1).
# Marker codes will be summed.
# 2017-09-21 16:05:27,630 WARNING : Same sample has at least two markers.
# 4151193: (112 and 35).
# Marker codes will be summed.
# 2017-09-21 16:05:27,631 WARNING : Same sample has at least two markers.
# 4164421: (111 and 21).
# Marker codes will be summed.
# 2017-09-21 16:05:27,639 WARNING : Same sample has at least two markers.
# 4175134: (112 and 31).
# Marker codes will be summed.
# 2017-09-21 16:05:27,640 WARNING : Same sample has at least two markers.
# 4199541: (112 and 32).
# Marker codes will be summed.
# 2017-09-21 16:05:27,641 WARNING : Same sample has at least two markers.
# 4211503: (211 and 4).
# Marker codes will be summed.
# 2017-09-21 16:05:27,649 WARNING : Same sample has at least two markers.
# 4224299: (122 and 40).
# Marker codes will be summed.
# 2017-09-21 16:05:27,650 WARNING : Same sample has at least two markers.
# 4237094: (222 and 18).
# Marker codes will be summed.
# 2017-09-21 16:05:27,651 WARNING : Same sample has at least two markers.
# 4249040: (221 and 9).
# Marker codes will be summed.
# 2017-09-21 16:05:27,652 WARNING : Same sample has at least two markers.
# 4263584: (212 and 11).
# Marker codes will be summed.
# 2017-09-21 16:05:27,653 WARNING : Same sample has at least two markers.
# 4274646: (222 and 16).
# Marker codes will be summed.
# 2017-09-21 16:05:27,654 WARNING : Same sample has at least two markers.
# 4286075: (121 and 26).
# Marker codes will be summed.
# 2017-09-21 16:05:27,655 WARNING : Same sample has at least two markers.
# 4297671: (212 and 13).
# Marker codes will be summed.
# 2017-09-21 16:05:27,656 WARNING : Same sample has at least two markers.
# 4311366: (211 and 5).
# Marker codes will be summed.
# 2017-09-21 16:05:27,656 WARNING : Same sample has at least two markers.
# 4324195: (111 and 25).
# Marker codes will be summed.
# 2017-09-21 16:05:27,657 WARNING : Same sample has at least two markers.
# 4337606: (221 and 10).
# Marker codes will be summed.
# 2017-09-21 16:05:27,658 WARNING : Same sample has at least two markers.
# 4444083: (122 and 37).
# Marker codes will be summed.
# 2017-09-21 16:05:27,659 WARNING : Same sample has at least two markers.
# 4455412: (112 and 33).
# Marker codes will be summed.
# 2017-09-21 16:05:27,660 WARNING : Same sample has at least two markers.
# 4466808: (122 and 39).
# Marker codes will be summed.
# 2017-09-21 16:05:27,661 WARNING : Same sample has at least two markers.
# 4477637: (112 and 35).
# Marker codes will be summed.
# 2017-09-21 16:05:27,662 WARNING : Same sample has at least two markers.
# 4488450: (221 and 6).
# Marker codes will be summed.
# 2017-09-21 16:05:27,663 WARNING : Same sample has at least two markers.
# 4499529: (111 and 21).
# Marker codes will be summed.
# 2017-09-21 16:05:27,664 WARNING : Same sample has at least two markers.
# 4510375: (212 and 14).
# Marker codes will be summed.
# 2017-09-21 16:05:27,665 WARNING : Same sample has at least two markers.
# 4521287: (111 and 25).
# Marker codes will be summed.
# 2017-09-21 16:05:27,666 WARNING : Same sample has at least two markers.
# 4532150: (112 and 31).
# Marker codes will be summed.
# 2017-09-21 16:05:27,667 WARNING : Same sample has at least two markers.
# 4544129: (212 and 11).
# Marker codes will be summed.
# 2017-09-21 16:05:27,667 WARNING : Same sample has at least two markers.
# 4555924: (211 and 1).
# Marker codes will be summed.
# 2017-09-21 16:05:27,668 WARNING : Same sample has at least two markers.
# 4567403: (121 and 28).
# Marker codes will be summed.
# 2017-09-21 16:05:27,669 WARNING : Same sample has at least two markers.
# 4580382: (222 and 20).
# Marker codes will be summed.
# 2017-09-21 16:05:27,673 WARNING : Same sample has at least two markers.
# 4591594: (221 and 7).
# Marker codes will be summed.
# 2017-09-21 16:05:27,683 WARNING : Same sample has at least two markers.
# 4602890: (222 and 17).
# Marker codes will be summed.
# 2017-09-21 16:05:27,684 WARNING : Same sample has at least two markers.
# 4613836: (112 and 34).
# Marker codes will be summed.
# 2017-09-21 16:05:27,685 WARNING : Same sample has at least two markers.
# 4627381: (222 and 18).
# Marker codes will be summed.
# 2017-09-21 16:05:27,686 WARNING : Same sample has at least two markers.
# 4638743: (211 and 4).
# Marker codes will be summed.
# 2017-09-21 16:05:27,687 WARNING : Same sample has at least two markers.
# 4651338: (221 and 10).
# Marker codes will be summed.
# 2017-09-21 16:05:27,688 WARNING : Same sample has at least two markers.
# 4664017: (121 and 30).
# Marker codes will be summed.
# 2017-09-21 16:05:27,689 WARNING : Same sample has at least two markers.
# 4676012: (121 and 26).
# Marker codes will be summed.
# 2017-09-21 16:05:27,689 WARNING : Same sample has at least two markers.
# 4687258: (222 and 16).
# Marker codes will be summed.
# 2017-09-21 16:05:27,690 WARNING : Same sample has at least two markers.
# 4698721: (122 and 38).
# Marker codes will be summed.
# 2017-09-21 16:05:27,691 WARNING : Same sample has at least two markers.
# 4710583: (221 and 9).
# Marker codes will be summed.
# 2017-09-21 16:05:27,692 WARNING : Same sample has at least two markers.
# 4722495: (122 and 40).
# Marker codes will be summed.
# 2017-09-21 16:05:27,693 WARNING : Same sample has at least two markers.
# 4733541: (122 and 36).
# Marker codes will be summed.
# 2017-09-21 16:05:27,693 WARNING : Same sample has at least two markers.
# 4746236: (112 and 32).
# Marker codes will be summed.
# 2017-09-21 16:05:27,694 WARNING : Same sample has at least two markers.
# 4757549: (211 and 3).
# Marker codes will be summed.
# 2017-09-21 16:05:27,695 WARNING : Same sample has at least two markers.
# 4770327: (111 and 23).
# Marker codes will be summed.
# 2017-09-21 16:05:27,696 WARNING : Same sample has at least two markers.
# 4781323: (121 and 27).
# Marker codes will be summed.
# 2017-09-21 16:05:27,697 WARNING : Same sample has at least two markers.
# 4792835: (212 and 13).
# Marker codes will be summed.
# 2017-09-21 16:05:27,697 WARNING : Same sample has at least two markers.
# 4804031: (212 and 15).
# Marker codes will be summed.
# 2017-09-21 16:05:27,698 WARNING : Same sample has at least two markers.
# 4817259: (222 and 19).
# Marker codes will be summed.
# 2017-09-21 16:05:27,699 WARNING : Same sample has at least two markers.
# 4828372: (211 and 5).
# Marker codes will be summed.
# 2017-09-21 16:05:27,700 WARNING : Same sample has at least two markers.
# 4839751: (212 and 12).
# Marker codes will be summed.
# 2017-09-21 16:05:27,701 WARNING : Same sample has at least two markers.
# 4874455: (211 and 2).
# Marker codes will be summed.
# 2017-09-21 16:05:27,702 WARNING : Same sample has at least two markers.
# 4886400: (111 and 22).
# Marker codes will be summed.
# 2017-09-21 16:05:27,702 WARNING : Same sample has at least two markers.
# 4897463: (121 and 29).
# Marker codes will be summed.
# 2017-09-21 16:05:27,703 WARNING : Same sample has at least two markers.
# 4930993: (111 and 25).
# Marker codes will be summed.
# 2017-09-21 16:05:27,704 WARNING : Same sample has at least two markers.
# 4942789: (211 and 3).
# Marker codes will be summed.
# 2017-09-21 16:05:27,705 WARNING : Same sample has at least two markers.
# 4954501: (111 and 21).
# Marker codes will be summed.
# 2017-09-21 16:05:27,706 WARNING : Same sample has at least two markers.
# 4967179: (212 and 13).
# Marker codes will be summed.
# 2017-09-21 16:05:27,706 WARNING : Same sample has at least two markers.
# 4978475: (212 and 12).
# Marker codes will be summed.
# 2017-09-21 16:05:27,707 WARNING : Same sample has at least two markers.
# 4990471: (222 and 20).
# Marker codes will be summed.
# 2017-09-21 16:05:27,708 WARNING : Same sample has at least two markers.
# 5001383: (112 and 33).
# Marker codes will be summed.
# 2017-09-21 16:05:27,709 WARNING : Same sample has at least two markers.
# 5012379: (112 and 31).
# Marker codes will be summed.
# 2017-09-21 16:05:27,710 WARNING : Same sample has at least two markers.
# 5024391: (212 and 14).
# Marker codes will be summed.
# 2017-09-21 16:05:27,710 WARNING : Same sample has at least two markers.
# 5036453: (122 and 36).
# Marker codes will be summed.
# 2017-09-21 16:05:27,712 WARNING : Same sample has at least two markers.
# 5047199: (222 and 16).
# Marker codes will be summed.
# 2017-09-21 16:05:27,712 WARNING : Same sample has at least two markers.
# 5059411: (221 and 10).
# Marker codes will be summed.
# 2017-09-21 16:05:27,713 WARNING : Same sample has at least two markers.
# 5071340: (111 and 22).
# Marker codes will be summed.
# 2017-09-21 16:05:27,714 WARNING : Same sample has at least two markers.
# 5083502: (122 and 40).
# Marker codes will be summed.
# 2017-09-21 16:05:27,715 WARNING : Same sample has at least two markers.
# 5107427: (121 and 29).
# Marker codes will be summed.
# 2017-09-21 16:05:27,715 WARNING : Same sample has at least two markers.
# 5118223: (122 and 37).
# Marker codes will be summed.
# 2017-09-21 16:05:27,716 WARNING : Same sample has at least two markers.
# 5129868: (122 and 39).
# Marker codes will be summed.
# 2017-09-21 16:05:27,717 WARNING : Same sample has at least two markers.
# 5140964: (211 and 5).
# Marker codes will be summed.
# 2017-09-21 16:05:27,718 WARNING : Same sample has at least two markers.
# 5152843: (221 and 8).
# Marker codes will be summed.
# 2017-09-21 16:05:27,719 WARNING : Same sample has at least two markers.
# 5164389: (221 and 6).
# Marker codes will be summed.
# 2017-09-21 16:05:27,720 WARNING : Same sample has at least two markers.
# 5176617: (112 and 34).
# Marker codes will be summed.
# 2017-09-21 16:05:27,720 WARNING : Same sample has at least two markers.
# 5188363: (121 and 26).
# Marker codes will be summed.
# 2017-09-21 16:05:27,721 WARNING : Same sample has at least two markers.
# 5199759: (211 and 2).
# Marker codes will be summed.
# 2017-09-21 16:05:27,722 WARNING : Same sample has at least two markers.
# 5211238: (222 and 17).
# Marker codes will be summed.
# 2017-09-21 16:05:27,723 WARNING : Same sample has at least two markers.
# 5222933: (112 and 32).
# Marker codes will be summed.
# 2017-09-21 16:05:27,724 WARNING : Same sample has at least two markers.
# 5234929: (222 and 19).
# Marker codes will be summed.
# 2017-09-21 16:05:27,725 WARNING : Same sample has at least two markers.
# 5245875: (222 and 18).
# Marker codes will be summed.
# 2017-09-21 16:05:27,725 WARNING : Same sample has at least two markers.
# 5258437: (211 and 4).
# Marker codes will be summed.
# 2017-09-21 16:05:27,726 WARNING : Same sample has at least two markers.
# 5269499: (121 and 27).
# Marker codes will be summed.
# 2017-09-21 16:05:27,727 WARNING : Same sample has at least two markers.
# 5280812: (121 and 28).
# Marker codes will be summed.
# 2017-09-21 16:05:27,728 WARNING : Same sample has at least two markers.
# 5291641: (212 and 11).
# Marker codes will be summed.
# 2017-09-21 16:05:27,729 WARNING : Same sample has at least two markers.
# 5303370: (212 and 15).
# Marker codes will be summed.
# 2017-09-21 16:05:27,730 WARNING : Same sample has at least two markers.
# 5314049: (211 and 1).
# Marker codes will be summed.
# 2017-09-21 16:05:27,730 WARNING : Same sample has at least two markers.
# 5325028: (121 and 30).
# Marker codes will be summed.
# 2017-09-21 16:05:27,731 WARNING : Same sample has at least two markers.
# 5348153: (122 and 38).
# Marker codes will be summed.
# 2017-09-21 16:05:27,732 WARNING : Same sample has at least two markers.
# 5359382: (112 and 35).
# Marker codes will be summed.
# 2017-09-21 16:05:27,733 WARNING : Same sample has at least two markers.
# 5370345: (221 and 9).
# Marker codes will be summed.
# 2017-09-21 16:05:27,734 WARNING : Same sample has at least two markers.
# 5436170: (221 and 9).
# Marker codes will be summed.
# 2017-09-21 16:05:27,735 WARNING : Same sample has at least two markers.
# 5448099: (222 and 20).
# Marker codes will be summed.
# 2017-09-21 16:05:27,736 WARNING : Same sample has at least two markers.
# 5459478: (112 and 31).
# Marker codes will be summed.
# 2017-09-21 16:05:27,736 WARNING : Same sample has at least two markers.
# 5471623: (111 and 23).
# Marker codes will be summed.
# 2017-09-21 16:05:27,737 WARNING : Same sample has at least two markers.
# 5482369: (121 and 28).
# Marker codes will be summed.
# 2017-09-21 16:05:27,738 WARNING : Same sample has at least two markers.
# 5494032: (211 and 1).
# Marker codes will be summed.
# 2017-09-21 16:05:27,739 WARNING : Same sample has at least two markers.
# 5504911: (212 and 15).
# Marker codes will be summed.
# 2017-09-21 16:05:27,740 WARNING : Same sample has at least two markers.
# 5516190: (211 and 2).
# Marker codes will be summed.
# 2017-09-21 16:05:27,741 WARNING : Same sample has at least two markers.
# 5527852: (212 and 12).
# Marker codes will be summed.
# 2017-09-21 16:05:27,741 WARNING : Same sample has at least two markers.
# 5538981: (222 and 16).
# Marker codes will be summed.
# 2017-09-21 16:05:27,742 WARNING : Same sample has at least two markers.
# 5550260: (121 and 29).
# Marker codes will be summed.
# 2017-09-21 16:05:27,743 WARNING : Same sample has at least two markers.
# 5562023: (111 and 25).
# Marker codes will be summed.
# 2017-09-21 16:05:27,744 WARNING : Same sample has at least two markers.
# 5572486: (122 and 39).
# Marker codes will be summed.
# 2017-09-21 16:05:27,745 WARNING : Same sample has at least two markers.
# 5583281: (122 and 38).
# Marker codes will be summed.
# 2017-09-21 16:05:27,746 WARNING : Same sample has at least two markers.
# 5594594: (112 and 34).
# Marker codes will be summed.
# 2017-09-21 16:05:27,746 WARNING : Same sample has at least two markers.
# 5606573: (211 and 5).
# Marker codes will be summed.
# 2017-09-21 16:05:27,747 WARNING : Same sample has at least two markers.
# 5618768: (221 and 8).
# Marker codes will be summed.
# ...
# Marker codes will be summed.
# 2017-09-21 16:05:27,783 WARNING : Same sample has at least two markers.
# 6207497: (122 and 37).
# Marker codes will be summed.
# 2017-09-21 16:05:27,783 WARNING : Same sample has at least two markers.
# 6231055: (121 and 28).
# Marker codes will be summed.
# 2017-09-21 16:05:27,784 WARNING : Same sample has at least two markers.
# 6242434: (111 and 25).
# Marker codes will be summed.
# 2017-09-21 16:05:27,785 WARNING : Same sample has at least two markers.
# 6254279: (111 and 23).
# Marker codes will be summed.
# 2017-09-21 16:05:27,786 WARNING : Same sample has at least two markers.
# 6289833: (211 and 1).
# Marker codes will be summed.
# 2017-09-21 16:05:27,787 WARNING : Same sample has at least two markers.
# 6300912: (222 and 17).
# Marker codes will be summed.
# 2017-09-21 16:05:27,787 WARNING : Same sample has at least two markers.
# 6312074: (212 and 11).
# Marker codes will be summed.
# 2017-09-21 16:05:27,788 WARNING : Same sample has at least two markers.
# 6322720: (211 and 2).
# Marker codes will be summed.
# 2017-09-21 16:05:27,789 WARNING : Same sample has at least two markers.
# 6334316: (122 and 40).
# Marker codes will be summed.
# 2017-09-21 16:05:27,790 WARNING : Same sample has at least two markers.
# 6346095: (121 and 29).
# Marker codes will be summed.
# 2017-09-21 16:05:27,790 WARNING : Same sample has at least two markers.
# 6356941: (211 and 3).
# Marker codes will be summed.
# 2017-09-21 16:05:27,791 WARNING : Same sample has at least two markers.
# 6367687: (121 and 27).
# Marker codes will be summed.
# 2017-09-21 16:05:27,792 WARNING : Same sample has at least two markers.
# 6377833: (212 and 15).
# Marker codes will be summed.
# 2017-09-21 16:05:27,793 WARNING : Same sample has at least two markers.
# 6389262: (112 and 32).
# Marker codes will be summed.
# 2017-09-21 16:05:27,794 WARNING : Same sample has at least two markers.
# 6400758: (212 and 14).
# Marker codes will be summed.
# 2017-09-21 16:05:27,794 WARNING : Same sample has at least two markers.
# 6429868: (121 and 26).
# Marker codes will be summed.
# 2017-09-21 16:05:27,795 WARNING : Same sample has at least two markers.
# 6440781: (211 and 1).
# Marker codes will be summed.
# 2017-09-21 16:05:27,796 WARNING : Same sample has at least two markers.
# 6451527: (111 and 24).
# Marker codes will be summed.
# 2017-09-21 16:05:27,797 WARNING : Same sample has at least two markers.
# 6463939: (221 and 7).
# Marker codes will be summed.
# 2017-09-21 16:05:27,797 WARNING : Same sample has at least two markers.
# 6474618: (111 and 23).
# Marker codes will be summed.
# 2017-09-21 16:05:27,798 WARNING : Same sample has at least two markers.
# 6485397: (211 and 3).
# Marker codes will be summed.
# 2017-09-21 16:05:27,799 WARNING : Same sample has at least two markers.
# 6496310: (211 and 5).
# Marker codes will be summed.
# 2017-09-21 16:05:27,800 WARNING : Same sample has at least two markers.
# 6508539: (121 and 30).
# Marker codes will be summed.
# 2017-09-21 16:05:27,800 WARNING : Same sample has at least two markers.
# 6520551: (121 and 29).
# Marker codes will be summed.
# 2017-09-21 16:05:27,801 WARNING : Same sample has at least two markers.
# 6531597: (222 and 16).
# Marker codes will be summed.
# 2017-09-21 16:05:27,802 WARNING : Same sample has at least two markers.
# 6542559: (212 and 11).
# Marker codes will be summed.
# 2017-09-21 16:05:27,803 WARNING : Same sample has at least two markers.
# 6553422: (221 and 6).
# Marker codes will be summed.
# 2017-09-21 16:05:27,804 WARNING : Same sample has at least two markers.
# 6564468: (122 and 39).
# Marker codes will be summed.
# 2017-09-21 16:05:27,804 WARNING : Same sample has at least two markers.
# 6575147: (112 and 33).
# Marker codes will be summed.
# 2017-09-21 16:05:27,805 WARNING : Same sample has at least two markers.
# 6586293: (112 and 32).
# Marker codes will be summed.
# 2017-09-21 16:05:27,806 WARNING : Same sample has at least two markers.
# 6598205: (222 and 17).
# Marker codes will be summed.
# 2017-09-21 16:05:27,807 WARNING : Same sample has at least two markers.
# 6609201: (121 and 28).
# Marker codes will be summed.
# 2017-09-21 16:05:27,807 WARNING : Same sample has at least two markers.
# 6619663: (112 and 31).
# Marker codes will be summed.
# 2017-09-21 16:05:27,808 WARNING : Same sample has at least two markers.
# 6641555: (211 and 4).
# Marker codes will be summed.
# 2017-09-21 16:05:27,809 WARNING : Same sample has at least two markers.
# 6652185: (212 and 14).
# Marker codes will be summed.
# 2017-09-21 16:05:27,810 WARNING : Same sample has at least two markers.
# 6663997: (111 and 22).
# Marker codes will be summed.
# 2017-09-21 16:05:27,810 WARNING : Same sample has at least two markers.
# 6674610: (221 and 9).
# Marker codes will be summed.
# 2017-09-21 16:05:27,811 WARNING : Same sample has at least two markers.
# 6685455: (112 and 34).
# Marker codes will be summed.
# 2017-09-21 16:05:27,812 WARNING : Same sample has at least two markers.
# 6696301: (221 and 10).
# Marker codes will be summed.
# 2017-09-21 16:05:27,813 WARNING : Same sample has at least two markers.
# 6707514: (212 and 13).
# Marker codes will be summed.
# 2017-09-21 16:05:27,814 WARNING : Same sample has at least two markers.
# 6719593: (112 and 35).
# Marker codes will be summed.
# 2017-09-21 16:05:27,815 WARNING : Same sample has at least two markers.
# 6730072: (222 and 20).
# Marker codes will be summed.
# 2017-09-21 16:05:27,815 WARNING : Same sample has at least two markers.
# 6740935: (111 and 21).
# Marker codes will be summed.
# 2017-09-21 16:05:27,816 WARNING : Same sample has at least two markers.
# 6752747: (222 and 18).
# Marker codes will be summed.
# 2017-09-21 16:05:27,817 WARNING : Same sample has at least two markers.
# 6763609: (122 and 36).
# Marker codes will be summed.
# 2017-09-21 16:05:27,818 WARNING : Same sample has at least two markers.
# 6775905: (212 and 15).
# Marker codes will be summed.
# 2017-09-21 16:05:27,818 WARNING : Same sample has at least two markers.
# 6787201: (121 and 27).
# Marker codes will be summed.
# 2017-09-21 16:05:27,819 WARNING : Same sample has at least two markers.
# 6798413: (211 and 2).
# Marker codes will be summed.
# 2017-09-21 16:05:27,820 WARNING : Same sample has at least two markers.
# 6809292: (122 and 37).
# Marker codes will be summed.
# 2017-09-21 16:05:27,821 WARNING : Same sample has at least two markers.
# 6821771: (222 and 19).
# Marker codes will be summed.
# 2017-09-21 16:05:27,821 WARNING : Same sample has at least two markers.
# 6833333: (122 and 40).
# Marker codes will be summed.
# 2017-09-21 16:05:27,822 WARNING : Same sample has at least two markers.
# 6843963: (122 and 38).
# Marker codes will be summed.
# 2017-09-21 16:05:27,823 WARNING : Same sample has at least two markers.
# 6854542: (111 and 25).
# Marker codes will be summed.
# 2017-09-21 16:05:27,824 WARNING : Same sample has at least two markers.
# 6865421: (221 and 8).
# Marker codes will be summed.
# 2017-09-21 16:05:27,824 WARNING : Same sample has at least two markers.
# 6914453: (221 and 8).
# Marker codes will be summed.
# 2017-09-21 16:05:27,825 WARNING : Same sample has at least two markers.
# 6925432: (111 and 24).
# Marker codes will be summed.
# 2017-09-21 16:05:27,826 WARNING : Same sample has at least two markers.
# 6936511: (211 and 4).
# Marker codes will be summed.
# 2017-09-21 16:05:27,827 WARNING : Same sample has at least two markers.
# 6947724: (121 and 28).
# Marker codes will be summed.
# 2017-09-21 16:05:27,827 WARNING : Same sample has at least two markers.
# 6958703: (212 and 11).
# Marker codes will be summed.
# 2017-09-21 16:05:27,828 WARNING : Same sample has at least two markers.
# 6971548: (212 and 14).
# Marker codes will be summed.
# 2017-09-21 16:05:27,829 WARNING : Same sample has at least two markers.
# 6982311: (211 and 3).
# Marker codes will be summed.
# 2017-09-21 16:05:27,830 WARNING : Same sample has at least two markers.
# 6993457: (121 and 30).
# Marker codes will be summed.
# 2017-09-21 16:05:27,831 WARNING : Same sample has at least two markers.
# 7004269: (222 and 17).
# Marker codes will be summed.
# 2017-09-21 16:05:27,831 WARNING : Same sample has at least two markers.
# 7015881: (112 and 32).
# Marker codes will be summed.
# 2017-09-21 16:05:27,832 WARNING : Same sample has at least two markers.
# 7027044: (222 and 18).
# Marker codes will be summed.
# 2017-09-21 16:05:27,833 WARNING : Same sample has at least two markers.
# 7039623: (122 and 36).
# Marker codes will be summed.
# 2017-09-21 16:05:27,834 WARNING : Same sample has at least two markers.
# 7050502: (111 and 21).
# Marker codes will be summed.
# 2017-09-21 16:05:27,835 WARNING : Same sample has at least two markers.
# 7073093: (122 and 39).
# Marker codes will be summed.
# 2017-09-21 16:05:27,835 WARNING : Same sample has at least two markers.
# 7084922: (112 and 33).
# Marker codes will be summed.
# 2017-09-21 16:05:27,836 WARNING : Same sample has at least two markers.
# 7095935: (112 and 31).
# Marker codes will be summed.
# 2017-09-21 16:05:27,837 WARNING : Same sample has at least two markers.
# 7106747: (121 and 27).
# Marker codes will be summed.
# 2017-09-21 16:05:27,838 WARNING : Same sample has at least two markers.
# 7118626: (112 and 34).
# Marker codes will be summed.
# 2017-09-21 16:05:27,838 WARNING : Same sample has at least two markers.
# 7129155: (221 and 9).
# Marker codes will be summed.
# 2017-09-21 16:05:27,839 WARNING : Same sample has at least two markers.
# 7140168: (212 and 15).
# Marker codes will be summed.
# 2017-09-21 16:05:27,840 WARNING : Same sample has at least two markers.
# 7151780: (111 and 23).
# Marker codes will be summed.
# 2017-09-21 16:05:27,841 WARNING : Same sample has at least two markers.
# 7164092: (222 and 19).
# Marker codes will be summed.
# 2017-09-21 16:05:27,842 WARNING : Same sample has at least two markers.
# 7174838: (212 and 12).
# Marker codes will be summed.
# 2017-09-21 16:05:27,843 WARNING : Same sample has at least two markers.
# 7185301: (122 and 37).
# Marker codes will be summed.
# 2017-09-21 16:05:27,843 WARNING : Same sample has at least two markers.
# 7195997: (211 and 2).
# Marker codes will be summed.
# 2017-09-21 16:05:27,844 WARNING : Same sample has at least two markers.
# 7207093: (221 and 6).
# Marker codes will be summed.
# 2017-09-21 16:05:27,845 WARNING : Same sample has at least two markers.
# 7218389: (121 and 26).
# Marker codes will be summed.
# 2017-09-21 16:05:27,846 WARNING : Same sample has at least two markers.
# 7229501: (222 and 16).
# Marker codes will be summed.
# 2017-09-21 16:05:27,846 WARNING : Same sample has at least two markers.
# 7241130: (222 and 20).
# Marker codes will be summed.
# 2017-09-21 16:05:27,847 WARNING : Same sample has at least two markers.
# 7263922: (122 and 40).
# Marker codes will be summed.
# 2017-09-21 16:05:27,848 WARNING : Same sample has at least two markers.
# 7274501: (211 and 5).
# Marker codes will be summed.
# 2017-09-21 16:05:27,849 WARNING : Same sample has at least two markers.
# 7286247: (121 and 29).
# Marker codes will be summed.
# 2017-09-21 16:05:27,849 WARNING : Same sample has at least two markers.
# 7297026: (122 and 38).
# Marker codes will be summed.
# 2017-09-21 16:05:27,850 WARNING : Same sample has at least two markers.
# 7320734: (221 and 7).
# Marker codes will be summed.
# 2017-09-21 16:05:27,851 WARNING : Same sample has at least two markers.
# 7332279: (112 and 35).
# Marker codes will be summed.
# 2017-09-21 16:05:27,852 WARNING : Same sample has at least two markers.
# 7353438: (111 and 22).
# Marker codes will be summed.
# 2017-09-21 16:05:27,853 WARNING : Same sample has at least two markers.
# 7439722: (212 and 14).
# Marker codes will be summed.
# 2017-09-21 16:05:27,854 WARNING : Same sample has at least two markers.
# 7450835: (121 and 30).
# Marker codes will be summed.
# 2017-09-21 16:05:27,855 WARNING : Same sample has at least two markers.
# 7462197: (222 and 17).
# Marker codes will be summed.
# 2017-09-21 16:05:27,856 WARNING : Same sample has at least two markers.
# 7473526: (121 and 27).
# Marker codes will be summed.
# 2017-09-21 16:05:27,857 WARNING : Same sample has at least two markers.
# 7484472: (111 and 23).
# Marker codes will be summed.
# 2017-09-21 16:05:27,857 WARNING : Same sample has at least two markers.
# 7495435: (112 and 32).
# Marker codes will be summed.
# 2017-09-21 16:05:27,858 WARNING : Same sample has at least two markers.
# 7505981: (211 and 5).
# Marker codes will be summed.
# 2017-09-21 16:05:27,859 WARNING : Same sample has at least two markers.
# 7517476: (221 and 10).
# Marker codes will be summed.
# 2017-09-21 16:05:27,860 WARNING : Same sample has at least two markers.
# 7528522: (111 and 24).
# Marker codes will be summed.
# 2017-09-21 16:05:27,861 WARNING : Same sample has at least two markers.
# 7540668: (221 and 6).
# Marker codes will be summed.
# 2017-09-21 16:05:27,862 WARNING : Same sample has at least two markers.
# 7551530: (122 and 38).
# Marker codes will be summed.
# 2017-09-21 16:05:27,862 WARNING : Same sample has at least two markers.
# 7562409: (122 and 39).
# Marker codes will be summed.
# 2017-09-21 16:05:27,863 WARNING : Same sample has at least two markers.
# 7573172: (211 and 1).
# Marker codes will be summed.
# 2017-09-21 16:05:27,864 WARNING : Same sample has at least two markers.
# 7583651: (222 and 20).
# Marker codes will be summed.
# 2017-09-21 16:05:27,865 WARNING : Same sample has at least two markers.
# 7594731: (211 and 2).
# Marker codes will be summed.
# 2017-09-21 16:05:27,866 WARNING : Same sample has at least two markers.
# 7606643: (212 and 11).
# Marker codes will be summed.
# 2017-09-21 16:05:27,867 WARNING : Same sample has at least two markers.
# 7618089: (112 and 33).
# Marker codes will be summed.
# 2017-09-21 16:05:27,868 WARNING : Same sample has at least two markers.
# 7628968: (122 and 40).
# Marker codes will be summed.
# 2017-09-21 16:05:27,869 WARNING : Same sample has at least two markers.
# 7641780: (112 and 35).
# Marker codes will be summed.
# 2017-09-21 16:05:27,869 WARNING : Same sample has at least two markers.
# 7652626: (222 and 16).
# Marker codes will be summed.
# 2017-09-21 16:05:27,870 WARNING : Same sample has at least two markers.
# 7663222: (122 and 36).
# Marker codes will be summed.
# 2017-09-21 16:05:27,871 WARNING : Same sample has at least two markers.
# 7675434: (221 and 8).
# Marker codes will be summed.
# 2017-09-21 16:05:27,872 WARNING : Same sample has at least two markers.
# 7686463: (212 and 13).
# Marker codes will be summed.
# 2017-09-21 16:05:27,872 WARNING : Same sample has at least two markers.
# 7697142: (111 and 25).
# Marker codes will be summed.
# 2017-09-21 16:05:27,873 WARNING : Same sample has at least two markers.
# 7707672: (212 and 15).
# Marker codes will be summed.
# 2017-09-21 16:05:27,874 WARNING : Same sample has at least two markers.
# 7718134: (221 and 9).
# Marker codes will be summed.
# 2017-09-21 16:05:27,875 WARNING : Same sample has at least two markers.
# 7730730: (212 and 12).
# Marker codes will be summed.
# 2017-09-21 16:05:27,876 WARNING : Same sample has at least two markers.
# 7741759: (111 and 21).
# Marker codes will be summed.
# 2017-09-21 16:05:27,877 WARNING : Same sample has at least two markers.
# 7752588: (111 and 22).
# Marker codes will be summed.
# 2017-09-21 16:05:27,877 WARNING : Same sample has at least two markers.
# 7776162: (121 and 28).
# Marker codes will be summed.
# 2017-09-21 16:05:27,878 WARNING : Same sample has at least two markers.
# 7786675: (211 and 4).
# Marker codes will be summed.
# 2017-09-21 16:05:27,879 WARNING : Same sample has at least two markers.
# 7797105: (222 and 19).
# Marker codes will be summed.
# 2017-09-21 16:05:27,880 WARNING : Same sample has at least two markers.
# 7809133: (221 and 7).
# Marker codes will be summed.
# 2017-09-21 16:05:27,880 WARNING : Same sample has at least two markers.
# 7819879: (121 and 29).
# Marker codes will be summed.
# 2017-09-21 16:05:27,881 WARNING : Same sample has at least two markers.
# 7830309: (121 and 26).
# Marker codes will be summed.
# 2017-09-21 16:05:27,882 WARNING : Same sample has at least two markers.
# 7840788: (222 and 18).
# Marker codes will be summed.
# 2017-09-21 16:05:27,883 WARNING : Same sample has at least two markers.
# 7851851: (112 and 34).
# Marker codes will be summed.
# 2017-09-21 16:05:27,884 WARNING : Same sample has at least two markers.
# 7862996: (122 and 37).
# Marker codes will be summed.
# 2017-09-21 16:05:27,885 WARNING : Same sample has at least two markers.
# 7873959: (112 and 31).
# Marker codes will be summed.

# %%
from braindecode.mne_ext.signalproc import mne_apply, resample_cnt
from braindecode.datautil.signalproc import bandpass_cnt

import numpy as np

def car_cnt(cnt):
    return mne_apply(lambda x: x - np.mean(x,axis=0, keepdims=True), cnt)

cnt = resample_cnt(cnt,500)
cnt = car_cnt(cnt)
cnt = mne_apply(lambda x: bandpass_cnt(x, 0.5,150.0, cnt.info['sfreq']), cnt)
# Out:
# 2017-09-21 16:07:10,776 WARNING : This is not causal, uses future data....
# 2017-09-21 16:07:10,777 INFO : Resampling from 1000.000000 to 500.000000 Hz.
# Creating RawArray with float64 data, n_channels=8, n_times=3980138
#     Range : 0 ... 3980137 =      0.000 ...  7960.274 secs
# Ready.

# %%
from fbcsp.experiment import CSPExperiment
from collections import OrderedDict
name_to_start_codes = OrderedDict([('Correct', [1,2,5,6,7,11,12,13,15,16,24,25,27,28,30]),
                                  ('Error', [3,4,8,9,10,14,17,18,19,20,21,22,23,26,29])])
epoch_ival_ms = [3300,7500]

# %%
from fbcsp.clean import EOGMaxMinCleaner, VarCleaner, apply_multiple_cleaners


cleaners = [EOGMaxMinCleaner(eog_cnt, epoch_ival_ms, name_to_start_codes, threshold=600),
           VarCleaner(whisker_percent=10, whisker_length=3)]
cleaned_cnt = apply_multiple_cleaners(cnt, epoch_ival_ms, name_to_start_codes, cleaners)
# Out:
# 2017-09-21 16:08:25,583 INFO : Apply EOGMaxMinCleaner...
# 2017-09-21 16:08:25,584 INFO : Cleaning...
# 2017-09-21 16:08:25,916 INFO : Trial per class:
# Counter({'Error': 225, 'Correct': 224})
# 2017-09-21 16:08:26,256 INFO : Trial per class:
# Counter({'Error': 225, 'Correct': 224})
# 2017-09-21 16:08:26,272 INFO : Rejected channels: []
# 2017-09-21 16:08:26,273 INFO : #Clean trials:     414
# 2017-09-21 16:08:26,274 INFO : #Rejected trials:  35
# 2017-09-21 16:08:26,275 INFO : Fraction Clean:    92.2%
# 2017-09-21 16:08:27,695 INFO : Apply VarCleaner...
# 2017-09-21 16:08:27,696 INFO : Cleaning...
# 2017-09-21 16:08:28,544 INFO : Trial per class:
# Counter({'Error': 207, 'Correct': 207})
# 2017-09-21 16:08:28,577 INFO : Rejected channels: []
# 2017-09-21 16:08:28,578 INFO : #Clean trials:     387
# 2017-09-21 16:08:28,578 INFO : #Rejected trials:  27
# 2017-09-21 16:08:28,579 INFO : Fraction Clean:    93.5%

# %%
exp = CSPExperiment(cleaned_cnt, name_to_start_codes, epoch_ival_ms,
                    min_freq = 0,
                    max_freq=36,#144, 
                    last_low_freq=30,
                    low_width=2,
                    high_width=6,
                    low_overlap=0,
                    high_overlap=0,
                    filt_order=3,
                    n_folds=10,
                    n_top_bottom_csp_filters=5,
                    n_selected_filterbands=None,
                    n_selected_features=20,
                    forward_steps=2,
                    backward_steps=1,)

# %%
from braindecode.datautil.trial_segment import create_signal_target, create_signal_target_from_raw_mne

from braindecode.datautil.signalproc import bandpass_cnt

from braindecode.datautil.iterators import get_balanced_batches

# %%
exp.run()
# Out:
# 2017-09-21 16:08:37,115 INFO : Trial per class:
# Counter({'Error': 195, 'Correct': 192})
# 2017-09-21 16:08:37,125 INFO : Running Training...
# 2017-09-21 16:08:37,126 INFO : Filter 1/17, 0.20 to 1.00 Hz
# 2017-09-21 16:08:38,712 INFO : Trial per class:
# Counter({'Error': 195, 'Correct': 192})
# 2017-09-21 16:08:38,720 INFO : Fold Nr: 1
# 2017-09-21 16:08:38,726 INFO : Class 1 vs 2
# 2017-09-21 16:08:39,174 INFO : Train: 58.33%
# 2017-09-21 16:08:39,178 INFO : Test:  51.28%
# 2017-09-21 16:08:39,181 INFO : Fold Nr: 2
